# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from joblib import dump

# %%
def topspeed_intervals(speed):
    if speed < 186:
        return 1
    elif 186 <= speed < 208:
        return 2
    else:
        return 3

def maximumpower_intervals(speed):
    if speed < 114:
        return 1
    elif 114 <= speed < 151:
        return 2
    else:
        return 3

def acceleration_intervals(speed):
    if speed < 9.5:
        return 1
    elif 9.5 <= speed < 11.4:
        return 2
    else:
        return 3

# %%
cars_data = pd.read_csv('clean.csv')
cars_data['TopSpeed'] = cars_data['TopSpeed'].apply(topspeed_intervals)
cars_data['TopSpeed'].value_counts()
# Out:
# TopSpeed
# 1    8529
# 3    8440
# 2    8313
# Name: count, dtype: int64

# %%
cars_data['MaximumPower'] = cars_data['MaximumPower'].apply(maximumpower_intervals)
cars_data['MaximumPower'].value_counts()
# Out:
# MaximumPower
# 2    8630
# 1    8500
# 3    8152
# Name: count, dtype: int64

# %%
cars_data['Acceleration'] = cars_data['Acceleration'].apply(acceleration_intervals)
cars_data['Acceleration'].value_counts()
# Out:
# Acceleration
# 1    8581
# 2    8379
# 3    8322
# Name: count, dtype: int64

# %%
cars_data.nunique()
# Out:
# CarName             23298
# EngineType             17
# FuelType                8
# MaximumPower            3
# MaximumTorque         313
# Drivetrain              3
# FuelConsumption        97
# Range                 923
# FuelTankCapacity       79
# CO2Emissions          219
# TopSpeed                3
# Acceleration            3
# dtype: int64

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25282 entries, 0 to 25281
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CarName           25282 non-null  object
#  1   EngineType        25282 non-null  object
#  2   FuelType          25282 non-null  object
#  3   MaximumPower      25282 non-null  int64
#  4   MaximumTorque     25282 non-null  int64
#  5   Drivetrain        25282 non-null  object
#  6   FuelConsumption   25282 non-null  float64
#  7   Range             25282 non-null  int64
#  8   FuelTankCapacity  25282 non-null  float64
#  9   CO2Emissions      25282 non-null  int64
#  10  TopSpeed          25282 non-null  int64
#  11  Acceleration      25282 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 2.3+ MB

# %%
label_encoder_dict = {}

for col in ['CarName', 'EngineType', 'FuelType', 'Drivetrain']:
    label_encoder = LabelEncoder()
    cars_data[col] = label_encoder.fit_transform(cars_data[col])
    label_encoder_dict[col] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# Словарь замен категориальных значений
print(label_encoder_dict)
# Out:
# {'CarName': {'Abarth 500 1.4 16v T-JET 135HP': 0, 'Abarth 500 1.4 16v T-JET 140HP Sequential': 1, 'Abarth 500 595 1.4 16v T-JET 160HP': 2, 'Abarth 500 595 1.4 16v T-JET 160HP Sequential': 3, 'Abarth 500 595 Competizione 1.4 16v T-JET 160HP': 4, 'Abarth 500 595 Competizione 1.4 16v T-JET 160HP Sequential': 5, 'Abarth 500 595 Competizione 1.4 16v T-JET 180HP': 6, 'Abarth 500 595 Competizione 1.4 16v T-JET 180HP Sequential': 7, 'Abarth 500 595 Turismo 1.4 16v T-JET 160HP': 8, 'Abarth 500 595 Turismo 1.4 16v T-JET 160HP Sequential': 9, 'Abarth 500 595C 1.4 16v T-JET 160HP': 10, 'Abarth 500 595C 1.4 16v T-JET 160HP Sequential': 11, 'Abarth 500 595C Competizione 1.4 16v T-JET 160HP': 12, 'Abarth 500 595C Competizione 1.4 16v T-JET 160HP Sequential': 13, 'Abarth 500 695 Tributo Ferrari': 14, 'Abarth 500 C 1.4 16v T-JET 135HP': 15, 'Abarth 500 C 1.4 16v T-JET 140HP Sequential': 16, 'Abarth 500C 1.4 16v T-JET 135HP': 17, 'Abarth 500C 1.4 16v T-JET 140HP Sequential': 18, 'Abarth 500C 1.4 16v T-Jet 135HP': 19, 'Abarth 500C 1.4 16v T-Jet 140HP Sequential': 20, 'Abarth 500C 595C Competizione 1.4 16v T-JET 180HP': 21, 'Abarth 500C 595C Competizione 1.4 16v T-JET 180HP Sequential': 22, 'Abarth 500C 595C Turismo 1.4 16v T-JET 160HP': 23, 'Abarth 500C 595C Turismo 1.4 16v T-JET 160HP Sequential': 24, 'Abarth Grande Punto 1.4 16v T-Jet 155HP': 25, 'Abarth Punto Evo 1.4 16v MultiAir 165HP': 26, 'Abarth Punto Evo Scorpione 1.4 16v MultiAir 180HP': 27, 'Abarth Punto Evo SuperSport 1.4 16v MultiAir 180HP': 28, 'Alfa Romeo 145 1.4 TS': 29, 'Alfa Romeo 145 1.6 TS': 30, 'Alfa Romeo 145 1.8 TS': 31, 'Alfa Romeo 145 1.9 JTD': 32, 'Alfa Romeo 145 1.9 TD': 33, 'Alfa Romeo 145 2.0 TS 16v QV': 34, 'Alfa Romeo 146 1.4 TS': 35, 'Alfa Romeo 146 1.6 TS': 36, 'Alfa Romeo 146 1.8 TS': 37, 'Alfa Romeo 146 1.9 JTD': 38, 'Alfa Romeo 146 2.0 Ti': 39, 'Alfa Romeo 147 1.6 TS': 40, 'Alfa Romeo 147 1.6 TS eco': 41, 'Alfa Romeo 147 1.9 JTD': 42, 'Alfa Romeo 147 1.9 JTD 16v': 43, 'Alfa Romeo 147 1.9 JTD 8v Mjet': 44, 'Alfa Romeo 147 1.9 JTD Ducati Corse 3 doors': 45, 'Alfa Romeo 147 1.9 JTD Ducati Corse 5 doors': 46, 'Alfa Romeo 147 1.9 JTDm 16v Q2': 47, 'Alfa Romeo 147 2.0 TS': 48, 'Alfa Romeo 147 5p 1.6 TS 105HP Moving': 49, 'Alfa Romeo 147 5p 1.9 JTD 120HP Moving': 50, 'Alfa Romeo 156 1.6 TS': 51, 'Alfa Romeo 156 1.8 TS': 52, 'Alfa Romeo 156 1.9 JTD': 53, 'Alfa Romeo 156 1.9 JTD 16v': 54, 'Alfa Romeo 156 1.9 JTD 8v': 55, 'Alfa Romeo 156 2.0 JTS': 56, 'Alfa Romeo 156 2.0 TS': 57, 'Alfa Romeo 156 2.4 JTD': 58, 'Alfa Romeo 156 2.4 JTD 10v': 59, 'Alfa Romeo 156 2.4 JTD 20v': 60, 'Alfa Romeo 156 2.5 V6': 61, 'Alfa Romeo 156 Sportagon 1.6 Tin Spark': 62, 'Alfa Romeo 156 Sportagon 1.8 Tin Spark': 63, 'Alfa Romeo 156 Sportagon 1.9 JTD': 64, 'Alfa Romeo 156 Sportagon 1.9 JTD Multijet': 65, 'Alfa Romeo 156 Sportagon 2.0 JTS': 66, 'Alfa Romeo 156 Sportagon 2.4 JTD': 67, 'Alfa Romeo 156 Sportagon 2.4 JTD Multijet': 68, 'Alfa Romeo 156 Sportagon 2.5 V6 24v': 69, 'Alfa Romeo 159 1.8': 70, 'Alfa Romeo 159 1.8 TBi 200HP Sport Plus': 71, 'Alfa Romeo 159 1.9 JTDm 120HP Sport ECO': 72, 'Alfa Romeo 159 1.9 JTDm 120HP Sport Plus ECO': 73, 'Alfa Romeo 159 1.9 JTDm 16v': 74, 'Alfa Romeo 159 1.9 JTDm 8v': 75, 'Alfa Romeo 159 1.9 JTS': 76, 'Alfa Romeo 159 2.0 JTDm 170HP Sport Plus': 77, 'Alfa Romeo 159 2.0 JTDm 170HP Sport Plus ECO': 78, 'Alfa Romeo 159 2.2 JTS': 79, 'Alfa Romeo 159 2.4 JTDm': 80, 'Alfa Romeo 159 3.2 V6 JTS Q4': 81, 'Alfa Romeo 159 S 1.8 TBi 200HP Sport Plus': 82, 'Alfa Romeo 159 S 1.9 JTDm 120HP Sport ECO': 83, 'Alfa Romeo 159 S 1.9 JTDm 120HP Sport Plus ECO': 84, 'Alfa Romeo 159 S 2.0 JTDm 170HP Sport Plus': 85, 'Alfa Romeo 159 S 2.0 JTDm 170HP Sport Plus ECO': 86, 'Alfa Romeo 166 2.0 TS 16v': 87, 'Alfa Romeo 166 2.4 JTD': 88, 'Alfa Romeo 166 2.4 JTD 10v': 89, 'Alfa Romeo 166 2.4 JTD 20v': 90, 'Alfa Romeo 166 2.5 V6': 91, 'Alfa Romeo 166 2.5 V6 24v': 92, 'Alfa Romeo 4C 4C': 93, 'Alfa Romeo Brera 1.8 TBi 200HP': 94, 'Alfa Romeo Brera 2.0 JTDm 170HP': 95, 'Alfa Romeo Brera 2.2  ...

# %%
cars_data_not_balanced = cars_data
cars_data
# Out:
#        CarName  EngineType  FuelType  MaximumPower  MaximumTorque  Drivetrain  \
# 0        13247           4         0             1            215           1
# 1        17426           3         4             1            112           1
# 2        10239           9         4             3            300           2
# 3        21038           4         4             2            155           1
# 4         9803           4         4             3            240           2
# ...        ...         ...       ...           ...            ...         ...
# 25277    11706           4         0             2            280           1
# 25278    19155           4         4             3            262           1
# 25279    11700           4         0             1            260           1
# 25280    20137           4         4             3            250           2
# 25281    11699           4         0             1            240           1
#
#        FuelConsumption  Range  FuelTankCapacity  CO2Emissions  TopSpeed  \
# 0                  4.5   1111              50.0           120         1
# 1                  6.0    750              45.0           144         1
# 2                  9.7    721              70.0           231         3
# 3                  7.2    763              55.0           173         2
# 4                  8.3    746              62.0           198         3
# ...                ...    ...               ...           ...       ...
# 25277              7.1    732              52.0           189         2
# 25278              9.4    553              52.0           226         3
# 25279              4.5   1155              52.0           119         2
# 25280              8.5    423              36.0           202         3
# 25281              5.0   1040              52.0           159         1
#
#        Acceleration
# 0                 3
# 1                 3
# 2                 1
# 3                 3
# 4                 1
# ...             ...
# 25277             2
# 25278             1
# 25279             3
# 25280             1
# 25281             3
#
# [25282 rows x 12 columns]

# %% [markdown]
# 1. Model training and parameter selection using Grid Search

# %% [markdown]
# Balanced dataset

# %%
x = cars_data.drop("TopSpeed", axis=1)
y = cars_data['TopSpeed']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2 ,random_state=42)

# %% [markdown]
# a. K-nearest neighbors (KNN)

# %%
knn = GridSearchCV(estimator= KNeighborsClassifier(), param_grid={'n_neighbors': [3,5], 'algorithm': ['ball_tree', 'kd_tree', 'brute']})

#knn = KNeighborsClassifier(n_neighbors=100, algorithm="")
knn.fit(x_train, y_train)

# Вывод наилучших гиперпараметров и прогноза
print("Наилучшие гиперпараметры: ", knn.best_params_)

# Оценка точности модели на тестовом наборе
accuracy = knn.score(x_test, y_test)
print("Точность на тестовом наборе: ", accuracy)
# Out:
# Наилучшие гиперпараметры:  {'algorithm': 'ball_tree', 'n_neighbors': 3}
# Точность на тестовом наборе:  0.8518884714257465

# %%
print(knn.score(x_test.values, y_test.values))
knn.best_params_
# Out:
# 0.8518884714257465
# C:\Users\МашОбуч\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# {'algorithm': 'ball_tree', 'n_neighbors': 3}

# %%
y_pred = knn.predict(x_test.values)
matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7, 5))
sns.heatmap(matrix, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# C:\Users\МашОбуч\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Text(58.222222222222214, 0.5, 'Truth')

# %%
from sklearn.metrics import roc_auc_score

# Вычисление предсказанных вероятностей принадлежности классу
y_pred_proba = knn.predict_proba(x_test)

# Вычисление показателя ROC/AUC
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

# Вывод отчета классификации
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Вывод показателя ROC/AUC
print("ROC/AUC:", roc_auc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.87      0.89      0.88      1747
#            2       0.79      0.79      0.79      1642
#            3       0.90      0.88      0.89      1668
#
#     accuracy                           0.85      5057
#    macro avg       0.85      0.85      0.85      5057
# weighted avg       0.85      0.85      0.85      5057
#
# ROC/AUC: 0.9499344189442311

# %%
dump(knn, "knn_model.joblib")
# Out:
# ['knn_model.joblib']

# %% [markdown]
# b. Support Vector Classification (SVM)

# %% [markdown]
# c. Decision tree

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from joblib import dump

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [100],
              'gamma': [0.0001],
              'kernel': ['rbf']}

model = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3)

model.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.884 total time=  45.7s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.883 total time=  45.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.883 total time=  45.3s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.885 total time=  45.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.894 total time=  45.9s
# GridSearchCV(estimator=SVC(probability=True),
#              param_grid={'C': [100], 'gamma': [0.0001], 'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(model.best_params_)

# print how our model looks after hyper-parameter tuning
print(model.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=100, gamma=0.0001, probability=True)

# %%
print(model.score(x_test.values, y_test.values))
# Out:
# C:\Users\МашОбуч\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# 0.901324896183508

# %%
y_pred = model.predict(x_test.values)
matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7, 5))
sns.heatmap(matrix, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Real")
# Out:
# C:\Users\МашОбуч\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Text(58.222222222222214, 0.5, 'Real')

# %%
from sklearn.metrics import roc_auc_score

y_pred = model.predict(x_test)

y_decision = model.predict_proba(x_test)

roc_auc = roc_auc_score(y_test, y_decision, multi_class='ovr')

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("ROC/AUC:", roc_auc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.92      0.93      0.93      1747
#            2       0.85      0.86      0.86      1642
#            3       0.93      0.91      0.92      1668
#
#     accuracy                           0.90      5057
#    macro avg       0.90      0.90      0.90      5057
# weighted avg       0.90      0.90      0.90      5057
#
# ROC/AUC: 0.9637460799674346

# %%
x = cars_data.drop("TopSpeed", axis=1)
y = cars_data['TopSpeed']
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
treeCl = DecisionTreeClassifier()
model = GridSearchCV(estimator=treeCl,  param_grid={'max_depth' : [2, 3, 10, 'None'], 'criterion': ['gini', 'entropy']})
model.fit(x_train, y_train)
# Out:
# C:\Users\МашОбуч\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\МашОбуч\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\МашОбуч\lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\МашОбуч\lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\МашОбуч\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_depth' parameter of DecisionTreeClassifier must be an int in the range [1, inf) or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\МашОбуч\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.77037086 0.79035946 0.86815069        nan 0.77037086 0.78044439
#  0.86830879        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 10, 'None']})

# %%
print(model.score(x_test, y_test))
model.best_params_
# Out:
# 0.8707482993197279
# {'criterion': 'entropy', 'max_depth': 10}

# %%
y_pred = model.predict(x_test.values)
matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7, 5))
sns.heatmap(matrix, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# C:\Users\МашОбуч\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# Text(58.222222222222214, 0.5, 'Truth')

# %%
from sklearn.metrics import roc_auc_score

# Вывод отчета классификации
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.90      0.90      0.90      2126
#            2       0.80      0.83      0.81      2113
#            3       0.92      0.89      0.90      2082
#
#     accuracy                           0.87      6321
#    macro avg       0.87      0.87      0.87      6321
# weighted avg       0.87      0.87      0.87      6321

# %%
plt.figure(figsize=(25,20))
print(x_train)
plot_tree(model.best_estimator_, fontsize=12, feature_names=list(x_test.columns))
# Out:
#        CarName  EngineType  FuelType  MaximumPower  MaximumTorque  Drivetrain  \
# 13970    18410           4         4             2            210           1
# 8422      2109           6         0             3            400           2
# 24985    14320           4         0             1            137           1
# 5903      7086           4         4             2            161           1
# 21065    11710           4         4             2            155           1
# ...        ...         ...       ...           ...            ...         ...
# 13123    19951           4         4             1            145           1
# 19648    17851           3         4             1             95           1
# 9845     16598           4         0             2            340           1
# 10799    14701           4         0             1            160           1
# 2732      3813           4         4             2            160           1
#
#        FuelConsumption  Range  FuelTankCapacity  CO2Emissions  Acceleration
# 13970              8.3    746              62.0           202             2
# 8422               6.7   1044              70.0           179             1
# 24985              5.9   1118              66.0           137             3
# 5903               6.3    984              62.0           147             3
# 21065              6.1    852              52.0           143             3
# ...                ...    ...               ...           ...           ...
# 13123              7.6    684              52.0           177             3
# 19648              4.4    795              35.0           101             3
# 9845               5.2   1269              66.0           136             2
# 10799              4.6   1195              55.0           123             3
# 2732               7.0    857              60.0           163             3
#
# [18961 rows x 11 columns]
# [Text(0.41606809701492536, 0.9545454545454546, 'Acceleration <= 1.5\nentropy = 1.585\nsamples = 18961\nvalue = [6403, 6200, 6358]'),
#  Text(0.15614116915422885, 0.8636363636363636, 'MaximumPower <= 2.5\nentropy = 0.7\nsamples = 6442\nvalue = [66, 993, 5383]'),
#  Text(0.07067786069651741, 0.7727272727272727, 'MaximumTorque <= 209.0\nentropy = 1.092\nsamples = 1543\nvalue = [25, 663, 855]'),
#  Text(0.026492537313432835, 0.6818181818181818, 'MaximumPower <= 1.5\nentropy = 1.118\nsamples = 515\nvalue = [24, 341, 150]'),
#  Text(0.007960199004975124, 0.5909090909090909, 'MaximumTorque <= 149.5\nentropy = 0.995\nsamples = 37\nvalue = [17, 20, 0]'),
#  Text(0.003980099502487562, 0.5, 'FuelTankCapacity <= 44.5\nentropy = 0.523\nsamples = 17\nvalue = [15, 2, 0]'),
#  Text(0.001990049751243781, 0.4090909090909091, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0, 0]'),
#  Text(0.005970149253731343, 0.4090909090909091, 'Range <= 630.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.003980099502487562, 0.3181818181818182, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.007960199004975124, 0.3181818181818182, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.011940298507462687, 0.5, 'CO2Emissions <= 184.5\nentropy = 0.469\nsamples = 20\nvalue = [2, 18, 0]'),
#  Text(0.009950248756218905, 0.4090909090909091, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16, 0]'),
#  Text(0.013930348258706468, 0.4090909090909091, 'CarName <= 12654.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.011940298507462687, 0.3181818181818182, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.015920398009950248, 0.3181818181818182, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.045024875621890545, 0.5909090909090909, 'MaximumTorque <= 168.5\nentropy = 1.0\nsamples = 478\nvalue = [7, 321, 150]'),
#  Text(0.026865671641791045, 0.5, 'CarName <= 3261.0\nentropy = 0.625\nsamples = 111\nvalue = [4, 98, 9]'),
#  Text(0.021890547263681594, 0.4090909090909091, 'CarName <= 3118.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 3, 0]'),
#  Text(0.01990049751243781, 0.3181818181818182, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.023880597014925373, 0.3181818181818182, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.031840796019900496, 0.4090909090909091, 'MaximumTorque <= 159.0\nentropy = 0.425\nsamples = 104\nvalue = [0, 95, 9]'),
#  Text(0.027860696517412936, 0.3181818181818182, 'Range <= 673.0\nentropy = 0.693\nsamples = 43\nvalue = [0, 35, 8]'),
#  Text(0.025870646766169153, 0.22727272727272727, 'Range <= 605.0\nentropy = 0.89\nsamples = 26\nvalue = [0, 18, 8]'),
#  Text(0.023880597014925373, 0.13636363636363635, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.027860696517412936, 0.13636363636363635, 'MaximumTorque <= 154.0\nentropy = 0.985\nsamples = 14\nvalue = [0, 6, 8]'),
#  Text(0.025870646766169153, 0.045454545454545456, 'entropy = 0.971\nsamples = 10\nvalue = [0, 6, 4]'),
#  Text(0.029850746268656716, 0.045454545454545456, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.029850746268656716, 0.22727272727272727, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17, 0]'),
#  Text(0.03582089552238806, 0.3181818181818182, 'MaximumTorque <= 166.5\nentropy = 0.121\nsamples = 61\nvalue = [0, 60, 1]'),
#  Text(0.03383084577114428, 0.22727272727272727, 'entropy = 0.0\nsamples = 50\nvalue = [0, 50, 0]'),
#  Text(0.03781094527363184, 0.22727272727272727, 'MaximumTorque <= 167.5\nentropy = 0.439\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.03582089552238806, 0.13636363636363635, 'Drivetrain <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.03383084577114428, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.03781094527363184, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.03980099502487562, 0.13636363636363635, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.06318407960199005, 0.5, 'Drivetrain <= 1.5\nentropy = 1.024\nsamples = 367\nvalue = [3, 223, 141]'),
#  Text(0.050746268656716415, 0.4090909090909091, 'CO2Emissions <= 191.5\nentropy = 0.981\nsamples = 341\nvalue = [2, 220, 119]'),
#  Text(0.04378109452736319, 0.3181818181818182, 'CarName <= 690.0\nentropy = 0.868\nsamples = 254\nvalue = [1, 186, 67]'),
#  Text(0.041791044776119404, 0.22727272727272727, 'entropy = 0.0\nsamples = 46\nvalue = [0, 46, 0]'),
#  Text(0.045771144278606964, 0.22727272727272727, 'CarName <= 20989.5\nentropy = 0.948\nsamples = 208\nvalue = [1, 140, 67]'),
#  Text(0.04378109452736319, 0.13636363636363635, 'CarName <= 13383.0\nentropy = 0.918\nsamples = 200\nvalue = [1, 140, 59]'),
#  Text(0.041791044776119404, 0.045454545454545456, 'entropy = 1.061\nsamples = 99\nvalue = [1, 55, 43]'),
#  Text(0.045771144278606964, 0.045454545454545456, 'entropy = 0.631\nsamples = 101\nvalue = [0, 85, 16]'),
#  Text(0.04776119402985075, 0.13636363636363635, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8]'),
#  Text(0.05771144278606965, 0.3181818181818182, 'CarName <= 9081.0\nentropy = 1.048\nsamples = 87\nvalue = [1, 34, 52]'),
#  Text(0.05373134328358209, 0.22727272727272727, 'FuelConsumption <= 9.35\nentropy = 1.095\nsamples = 45\nvalue = [1, 27, 17]'),
#  Text(0.051741293532338306, 0.13636363636363635, 'MaximumTorque <= 188.0\nentropy = 1.132\nsamples = 40\nvalue = [1, 22, 17]'),
#  Text(0.04975124378109453, 0.045454545454545456, 'entropy = 1.109\nsamples = 34\nvalue = [1, 21, 12]'),
#  Text(0.05373134328358209, 0.045454545454545456, 'entropy = 0.65\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(0.05572139303482587, 0.13636363636363635, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.061691542288557215, 0.22727272727272727, 'MaximumTorque <= 186.5\nentropy = 0.65\nsamples = 42\nvalue = [0, 7, 35]'),
#  Text(0.05970149253731343, 0.13636363636363635, 'CarName <= 18195.5\nentropy = 0.855\nsamples = 25\nvalue = [0, 7, 18]'),
#  Text(0.05771144278606965, 0.045454545454545456, 'entropy = 0.61\nsamples = 20\nvalue = [0, 3, 17]'),
#  Text(0.061691542288557215, 0.045454545454545456, 'entropy = 0.722\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.06368159203980099, 0.13636363636363635, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 17]'),
#  Text(0.07562189054726368, 0.4090909090909091, 'FuelConsumption <= 9.05\nentropy = 0.744\nsamples = 26\nvalue = [1, 3, 22]'),
#  Text(0.07164179104477612, 0.3181818181818182, 'MaximumTorque <= 173.0\nentropy = 0.258\nsamples = 23\nvalue = [0, 1, 22]'),
#  Text(0.06965174129353234, 0.22727272727272727, 'CarName <= 14142.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.06766169154228856, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.07164179104477612, 0.13636363636363635, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.0736318407960199, 0.22727272727272727, 'entropy = 0.0\nsamples = 20\nvalue = [0, 0, 20]'),
#  Text(0.07960199004975124, 0.3181818181818182, 'CO2Emissions <= 255.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.07761194029850746, 0.22727272727272727, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.08159203980099503, 0.22727272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.11486318407960198, 0.6818181818181818, 'CO2Emissions <= 117.5\nentropy = 0.907\nsamples = 1028\nvalue = [1, 322, 705]'),
#  Text(0.09203980099502487, 0.5909090909090909, 'CO2Emissions <= 94.5\nentropy = 0.483\nsamples = 411\nvalue = [0, 43, 368]'),
#  Text(0.09004975124378109, 0.5, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0]'),
#  Text(0.09402985074626866, 0.5, 'EngineType <= 3.5\nentropy = 0.402\nsamples = 400\nvalue = [0, 32, 368]'),
#  Text(0.08557213930348259, 0.4090909090909091, 'CarName <= 2847.5\nentropy = 0.966\nsamples = 23\nvalue = [0, 14, 9]'),
#  Text(0.08358208955223881, 0.3181818181818182, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.08756218905472637, 0.3181818181818182, 'FuelTankCapacity <= 49.0\nentropy = 0.672\nsamples = 17\nvalue = [0, 14, 3]'),
#  Text(0.08557213930348259, 0.22727272727272727, 'Range <= 1152.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.08358208955223881, 0.13636363636363635, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.08756218905472637, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.08955223880597014, 0.22727272727272727, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(0.10248756218905472, 0.4090909090909091, 'FuelTankCapacity <= 50.5\nentropy = 0.277\nsamples = 377\nvalue = [0, 18, 359]'),
#  Text(0.09751243781094528, 0.3181818181818182, 'CO2Emissions <= 98.0\nentropy = 0.1\nsamples = 231\nvalue = [0, 3, 228]'),
#  Text(0.09353233830845771, 0.22727272727272727, 'CO2Emissions <= 96.0\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.09154228855721393, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.0955223880597015, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.10149253731343283, 0.22727272727272727, 'FuelConsumption <= 4.85\nentropy = 0.072\nsamples = 229\nvalue = [0, 2, 227]'),
#  Text(0.09950248756218906, 0.13636363636363635, 'entropy = 0.0\nsamples = 177\nvalue = [0, 0, 177]'),
#  Text(0.10348258706467661, 0.13636363636363635, 'MaximumTorque <= 280.0\nentropy = 0.235\nsamples = 52\nvalue = [0, 2, 50]'),
#  Text(0.10149253731343283, 0.045454545454545456, 'entropy = 0.0\nsamples = 47\nvalue = [0, 0, 47]'),
#  Text(0.1054726368159204, 0.045454545454545456, 'entropy = 0.971\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.10746268656716418, 0.3181818181818182, 'CarName <= 2834.5\nentropy = 0.478\nsamples = 146\nvalue = [0, 15, 131]'),
#  Text(0.1054726368159204, 0.22727272727272727, 'entropy = 0.0\nsamples = 43\nvalue = [0, 0, 43]'),
#  Text(0.10945273631840796, 0.22727272727272727, 'CarName <= 3832.0\nentropy = 0.599\nsamples = 103\nvalue = [0, 15, 88]'),
#  Text(0.10746268656716418, 0.13636363636363635, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.11144278606965174, 0.13636363636363635, 'Range <= 1219.0\nentropy = 0.342\nsamples = 94\nvalue = [0, 6, 88]'),
#  Text(0.10945273631840796, 0.045454545454545456, 'entropy = 0.991\nsamples = 9\nvalue = [0, 4, 5]'),
#  Text(0.11343283582089553, 0.045454545454545456, 'entropy = 0.161\nsamples = 85\nvalue = [0, 2, 83]'),
#  Text(0.1376865671641791, 0.5909090909090909, 'CarName <= 1483.5\nentropy = 1.009\nsamples = 617\nvalue = [1, 279, 337]'),
#  Text(0.12338308457711443, 0.5, 'CarName <= 493.5\nentropy = 0.557\nsamples = 100\nvalue = [0, 13, 87]'),
#  Text(0.12139303482587065, 0.4090909090909091, 'CO2Emissions <= 158.0\nentropy = 0.927\nsamples = 38\nvalue = [0, 13, 25]'),
#  Text(0.11940298507462686, 0.3181818181818182, 'MaximumTorque <= 307.5\nentropy = 0.9\nsamples = 19\nvalue = [0, 13, 6]'),
#  Text(0.11741293532338308, 0.22727272727272727, 'Range <= 825.5\nentropy = 1.0\nsamples = 12\nvalue = [0, 6, 6]'),
#  Text(0.1154228855721393, 0.13636363636363635, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.11940298507462686, 0.13636363636363635, 'CO2Emissions <= 134.0\nentropy = 0.811\nsamples = 8\nvalue = [0, 2, 6]'),
#  Text(0.11741293532338308, 0.045454545454545456, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.12139303482587065, 0.045454545454545456, 'entropy = 1.0\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.12139303482587065, 0.22727272727272727, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.12338308457711443, 0.3181818181818182, 'entropy = 0.0\nsamples = 19\nvalue = [0, 0, 19]'),
#  Text(0.1253731343283582, 0.4090909090909091, 'entropy = 0.0\nsamples = 62\nvalue = [0, 0, 62]'),
#  Text(0.15199004975124378, 0.5, 'Drivetrain <= 1.5\nentropy = 1.018\nsamples = 517\nvalue = [1, 266, 250]'),
#  Text(0.1407960199004975, 0.4090909090909091, 'FuelTankCapacity <= 65.5\nentropy = 0.989\nsamples = 467\nvalue = [0, 262, 205]'),
#  Text(0.13034825870646766, 0.3181818181818182, 'MaximumTorque <= 211.0\nentropy = 0.965\nsamples = 422\nvalue = [0, 257, 165]'),
#  Text(0.1253731343283582, 0.22727272727272727, 'CO2Emissions <= 140.0\nentropy = 0.469\nsamples = 30\nvalue = [0, 3, 27]'),
#  Text(0.12338308457711443, 0.13636363636363635, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.12736318407960198, 0.13636363636363635, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 27]'),
#  Text(0.13532338308457711, 0.22727272727272727, 'CarName <= 20100.0\nentropy = 0.936\nsamples = 392\nvalue = [0, 254, 138]'),
#  Text(0.13134328358208955, 0.13636363636363635, 'CarName <= 11474.5\nentropy = 0.985\nsamples = 269\nvalue = [0, 154, 115]'),
#  Text(0.12935323383084577, 0.045454545454545456, 'entropy = 0.753\nsamples = 148\nvalue = [0, 116, 32]'),
#  Text(0.13333333333333333, 0.045454545454545456, 'entropy = 0.898\nsamples = 121\nvalue = [0, 38, 83]'),
#  Text(0.13930348258706468, 0.13636363636363635, 'CarName <= 20415.0\nentropy = 0.695\nsamples = 123\nvalue = [0, 100, 23]'),
#  Text(0.1373134328358209, 0.045454545454545456, 'entropy = 0.0\nsamples = 55\nvalue = [0, 55, 0]'),
#  Text(0.14129353233830846, 0.045454545454545456, 'entropy = 0.923\nsamples = 68\nvalue = [0, 45, 23]'),
#  Text(0.15124378109452735, 0.3181818181818182, 'CarName <= 21837.5\nentropy = 0.503\nsamples = 45\nvalue = [0, 5, 40]'),
#  Text(0.14925373134328357, 0.22727272727272727, 'Drivetrain <= 0.5\nentropy = 0.276\nsamples = 42\nvalue = [0, 2, 40]'),
#  Text(0.1472636815920398, 0.13636363636363635, 'CO2Emissions <= 129.5\nentropy = 0.764\nsamples = 9\nvalue = [0, 2, 7]'),
#  Text(0.14527363184079603, 0.045454545454545456, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.14925373134328357, 0.045454545454545456, 'entropy = 0.918\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.15124378109452735, 0.13636363636363635, 'entropy = 0.0\nsamples = 33\nvalue = [0, 0, 33]'),
#  Text(0.15323383084577114, 0.22727272727272727, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.16318407960199005, 0.4090909090909091, 'Range <= 680.0\nentropy = 0.541\nsamples = 50\nvalue = [1, 4, 45]'),
#  Text(0.15920398009950248, 0.3181818181818182, 'MaximumTorque <= 260.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.1572139303482587, 0.22727272727272727, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.16119402985074627, 0.22727272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.16716417910447762, 0.3181818181818182, 'EngineType <= 3.5\nentropy = 0.254\nsamples = 47\nvalue = [0, 2, 45]'),
#  Text(0.16517412935323383, 0.22727272727272727, 'FuelConsumption <= 5.45\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.16318407960199005, 0.13636363636363635, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.16716417910447762, 0.13636363636363635, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.1691542288557214, 0.22727272727272727, 'entropy = 0.0\nsamples = 41\nvalue = [0, 0, 41]'),
#  Text(0.2416044776119403, 0.7727272727272727, 'CarName <= 2990.5\nentropy = 0.425\nsamples = 4899\nvalue = [41, 330, 4528]'),
#  Text(0.18706467661691542, 0.6818181818181818, 'FuelTankCapacity <= 74.0\nentropy = 0.039\nsamples = 1458\nvalue = [0, 6, 1452]'),
#  Text(0.1791044776119403, 0.5909090909090909, 'Range <= 999.5\nentropy = 0.016\nsamples = 1336\nvalue = [0, 2, 1334]'),
#  Text(0.1771144278606965, 0.5, 'entropy = 0.0\nsamples = 777\nvalue = [0, 0, 777]'),
#  Text(0.18109452736318407, 0.5, 'Range <= 1095.0\nentropy = 0.034\nsamples = 559\nvalue = [0, 2, 557]'),
#  Text(0.1791044776119403, 0.4090909090909091, 'Range <= 1093.5\nentropy = 0.088\nsamples = 181\nvalue = [0, 2, 179]'),
#  Text(0.17512437810945275, 0.3181818181818182, 'CO2Emissions <= 177.0\nentropy = 0.051\nsamples = 176\nvalue = [0, 1, 175]'),
#  Text(0.17313432835820897, 0.22727272727272727, 'entropy = 0.0\nsamples = 161\nvalue = [0, 0, 161]'),
#  Text(0.1771144278606965, 0.22727272727272727, 'EngineType <= 4.5\nentropy = 0.353\nsamples = 15\nvalue = [0, 1, 14]'),
#  Text(0.17512437810945275, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.1791044776119403, 0.13636363636363635, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 14]'),
#  Text(0.18308457711442785, 0.3181818181818182, 'Drivetrain <= 1.0\nentropy = 0.722\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.18109452736318407, 0.22727272727272727, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.18507462686567164, 0.22727272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.18308457711442785, 0.4090909090909091, 'entropy = 0.0\nsamples = 378\nvalue = [0, 0, 378]'),
#  Text(0.19502487562189055, 0.5909090909090909, 'EngineType <= 4.5\nentropy = 0.208\nsamples = 122\nvalue = [0, 4, 118]'),
#  Text(0.19303482587064677, 0.5, 'CarName <= 1831.5\nentropy = 0.579\nsamples = 29\nvalue = [0, 4, 25]'),
#  Text(0.1890547263681592, 0.4090909090909091, 'CarName <= 1753.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.18706467661691542, 0.3181818181818182, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.191044776119403, 0.3181818181818182, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.19701492537313434, 0.4090909090909091, 'FuelTankCapacity <= 87.5\nentropy = 0.242\nsamples = 25\nvalue = [0, 1, 24]'),
#  Text(0.19502487562189055, 0.3181818181818182, 'entropy = 0.0\nsamples = 24\nvalue = [0, 0, 24]'),
#  Text(0.19900497512437812, 0.3181818181818182, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.19701492537313434, 0.5, 'entropy = 0.0\nsamples = 93\nvalue = [0, 0, 93]'),
#  Text(0.2961442786069652, 0.6818181818181818, 'Drivetrain <= 0.5\nentropy = 0.542\nsamples = 3441\nvalue = [41, 324, 3076]'),
#  Text(0.2449004975124378, 0.5909090909090909, 'CarName <= 9257.5\nentropy = 0.937\nsamples = 839\nvalue = [23, 187, 629]'),
#  Text(0.21567164179104478, 0.5, 'CarName <= 7631.5\nentropy = 1.3\nsamples = 238\nvalue = [18, 96, 124]'),
#  Text(0.20497512437810944, 0.4090909090909091, 'CarName <= 7398.5\nentropy = 0.692\nsamples = 97\nvalue = [0, 18, 79]'),
#  Text(0.20298507462686566, 0.3181818181818182, 'CarName <= 5790.5\nentropy = 0.924\nsamples = 53\nvalue = [0, 18, 35]'),
#  Text(0.19601990049751244, 0.22727272727272727, 'Range <= 679.0\nentropy = 0.75\nsamples = 42\nvalue = [0, 9, 33]'),
#  Text(0.19203980099502488, 0.13636363636363635, 'CO2Emissions <= 270.0\nentropy = 0.863\nsamples = 7\nvalue = [0, 5, 2]'),
#  Text(0.1900497512437811, 0.045454545454545456, 'entropy = 0.65\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.19402985074626866, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.2, 0.13636363636363635, 'CarName <= 3000.5\nentropy = 0.513\nsamples = 35\nvalue = [0, 4, 31]'),
#  Text(0.19800995024875623, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.2019900497512438, 0.045454545454545456, 'entropy = 0.33\nsamples = 33\nvalue = [0, 2, 31]'),
#  Text(0.2099502487562189, 0.22727272727272727, 'CO2Emissions <= 245.5\nentropy = 0.684\nsamples = 11\nvalue = [0, 9, 2]'),
#  Text(0.20796019900497512, 0.13636363636363635, 'Range <= 1187.5\nentropy = 0.469\nsamples = 10\nvalue = [0, 9, 1]'),
#  Text(0.20597014925373133, 0.045454545454545456, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.2099502487562189, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.21194029850746268, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.20696517412935322, 0.3181818181818182, 'entropy = 0.0\nsamples = 44\nvalue = [0, 0, 44]'),
#  Text(0.2263681592039801, 0.4090909090909091, 'FuelType <= 3.0\nentropy = 1.377\nsamples = 141\nvalue = [18, 78, 45]'),
#  Text(0.21791044776119403, 0.3181818181818182, 'MaximumTorque <= 263.5\nentropy = 1.012\nsamples = 82\nvalue = [9, 63, 10]'),
#  Text(0.21592039800995025, 0.22727272727272727, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.21990049751243781, 0.22727272727272727, 'MaximumTorque <= 445.5\nentropy = 0.738\nsamples = 75\nvalue = [2, 63, 10]'),
#  Text(0.21592039800995025, 0.13636363636363635, 'CarName <= 8756.5\nentropy = 0.31\nsamples = 54\nvalue = [0, 51, 3]'),
#  Text(0.21393034825870647, 0.045454545454545456, 'entropy = 0.0\nsamples = 49\nvalue = [0, 49, 0]'),
#  Text(0.21791044776119403, 0.045454545454545456, 'entropy = 0.971\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.22388059701492538, 0.13636363636363635, 'CO2Emissions <= 166.0\nentropy = 1.313\nsamples = 21\nvalue = [2, 12, 7]'),
#  Text(0.2218905472636816, 0.045454545454545456, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7]'),
#  Text(0.22587064676616916, 0.045454545454545456, 'entropy = 0.592\nsamples = 14\nvalue = [2, 12, 0]'),
#  Text(0.23482587064676616, 0.3181818181818182, 'CarName <= 7932.5\nentropy = 1.363\nsamples = 59\nvalue = [9, 15, 35]'),
#  Text(0.2298507462686567, 0.22727272727272727, 'FuelTankCapacity <= 89.5\nentropy = 0.684\nsamples = 11\nvalue = [9, 2, 0]'),
#  Text(0.22786069651741295, 0.13636363636363635, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.23184079601990049, 0.13636363636363635, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.23980099502487562, 0.22727272727272727, 'CarName <= 8642.5\nentropy = 0.843\nsamples = 48\nvalue = [0, 13, 35]'),
#  Text(0.23582089552238805, 0.13636363636363635, 'CarName <= 8516.5\nentropy = 0.562\nsamples = 38\nvalue = [0, 5, 33]'),
#  Text(0.23383084577114427, 0.045454545454545456, 'entropy = 0.994\nsamples = 11\nvalue = [0, 5, 6]'),
#  Text(0.23781094527363184, 0.045454545454545456, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 27]'),
#  Text(0.24378109452736318, 0.13636363636363635, 'Range <= 634.5\nentropy = 0.722\nsamples = 10\nvalue = [0, 8, 2]'),
#  Text(0.2417910447761194, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.24577114427860697, 0.045454545454545456, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.27412935323383086, 0.5, 'CarName <= 18602.0\nentropy = 0.681\nsamples = 601\nvalue = [5, 91, 505]'),
#  Text(0.2606965174129353, 0.4090909090909091, 'FuelTankCapacity <= 60.5\nentropy = 0.388\nsamples = 316\nvalue = [0, 24, 292]'),
#  Text(0.2537313432835821, 0.3181818181818182, 'CarName <= 10138.5\nentropy = 0.611\nsamples = 133\nvalue = [0, 20, 113]'),
#  Text(0.2517412935323383, 0.22727272727272727, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]'),
#  Text(0.2557213930348259, 0.22727272727272727, 'CarName <= 10168.5\nentropy = 0.726\nsamples = 99\nvalue = [0, 20, 79]'),
#  Text(0.2517412935323383, 0.13636363636363635, 'Range <= 838.5\nentropy = 0.845\nsamples = 11\nvalue = [0, 8, 3]'),
#  Text(0.24975124378109453, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.2537313432835821, 0.045454545454545456, 'entropy = 0.503\nsamples = 9\nvalue = [0, 8, 1]'),
#  Text(0.25970149253731345, 0.13636363636363635, 'MaximumTorque <= 245.0\nentropy = 0.575\nsamples = 88\nvalue = [0, 12, 76]'),
#  Text(0.25771144278606967, 0.045454545454545456, 'entropy = 0.918\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.26169154228855723, 0.045454545454545456, 'entropy = 0.461\nsamples = 82\nvalue = [0, 8, 74]'),
#  Text(0.2676616915422886, 0.3181818181818182, 'Range <= 575.0\nentropy = 0.152\nsamples = 183\nvalue = [0, 4, 179]'),
#  Text(0.2656716417910448, 0.22727272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.26965174129353237, 0.22727272727272727, 'FuelType <= 2.0\nentropy = 0.121\nsamples = 182\nvalue = [0, 3, 179]'),
#  Text(0.2676616915422886, 0.13636363636363635, 'MaximumTorque <= 370.0\nentropy = 0.253\nsamples = 71\nvalue = [0, 3, 68]'),
#  Text(0.2656716417910448, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.26965174129353237, 0.045454545454545456, 'entropy = 0.109\nsamples = 69\nvalue = [0, 1, 68]'),
#  Text(0.2716417910447761, 0.13636363636363635, 'entropy = 0.0\nsamples = 111\nvalue = [0, 0, 111]'),
#  Text(0.28756218905472636, 0.4090909090909091, 'Range <= 743.5\nentropy = 0.907\nsamples = 285\nvalue = [5, 67, 213]'),
#  Text(0.2796019900497512, 0.3181818181818182, 'CarName <= 18886.5\nentropy = 0.371\nsamples = 84\nvalue = [0, 6, 78]'),
#  Text(0.27761194029850744, 0.22727272727272727, 'CO2Emissions <= 270.0\nentropy = 0.845\nsamples = 22\nvalue = [0, 6, 16]'),
#  Text(0.27562189054726366, 0.13636363636363635, 'MaximumTorque <= 267.5\nentropy = 0.629\nsamples = 19\nvalue = [0, 3, 16]'),
#  Text(0.2736318407960199, 0.045454545454545456, 'entropy = 0.811\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.27761194029850744, 0.045454545454545456, 'entropy = 0.0\nsamples = 15\nvalue = [0, 0, 15]'),
#  Text(0.2796019900497512, 0.13636363636363635, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.281592039800995, 0.22727272727272727, 'entropy = 0.0\nsamples = 62\nvalue = [0, 0, 62]'),
#  Text(0.2955223880597015, 0.3181818181818182, 'CarName <= 19942.5\nentropy = 1.04\nsamples = 201\nvalue = [5, 61, 135]'),
#  Text(0.28756218905472636, 0.22727272727272727, 'CarName <= 19365.5\nentropy = 1.347\nsamples = 18\nvalue = [4, 11, 3]'),
#  Text(0.2835820895522388, 0.13636363636363635, 'Range <= 1114.0\nentropy = 0.779\nsamples = 13\nvalue = [0, 10, 3]'),
#  Text(0.281592039800995, 0.045454545454545456, 'entropy = 0.439\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.2855721393034826, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.2915422885572139, 0.13636363636363635, 'MaximumTorque <= 393.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.28955223880597014, 0.045454545454545456, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.2935323383084577, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3034825870646766, 0.22727272727272727, 'FuelTankCapacity <= 63.0\nentropy = 0.892\nsamples = 183\nvalue = [1, 50, 132]'),
#  Text(0.29950248756218906, 0.13636363636363635, 'CarName <= 23037.5\nentropy = 0.523\nsamples = 33\nvalue = [1, 2, 30]'),
#  Text(0.2975124378109453, 0.045454545454545456, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 27]'),
#  Text(0.30149253731343284, 0.045454545454545456, 'entropy = 1.459\nsamples = 6\nvalue = [1, 2, 3]'),
#  Text(0.3074626865671642, 0.13636363636363635, 'FuelTankCapacity <= 65.0\nentropy = 0.904\nsamples = 150\nvalue = [0, 48, 102]'),
#  Text(0.3054726368159204, 0.045454545454545456, 'entropy = 0.985\nsamples = 35\nvalue = [0, 20, 15]'),
#  Text(0.309452736318408, 0.045454545454545456, 'entropy = 0.801\nsamples = 115\nvalue = [0, 28, 87]'),
#  Text(0.34738805970149256, 0.5909090909090909, 'MaximumTorque <= 270.5\nentropy = 0.357\nsamples = 2602\nvalue = [18, 137, 2447]'),
#  Text(0.32238805970149254, 0.5, 'CO2Emissions <= 116.5\nentropy = 0.533\nsamples = 873\nvalue = [6, 89, 778]'),
#  Text(0.3154228855721393, 0.4090909090909091, 'Range <= 1193.5\nentropy = 0.634\nsamples = 25\nvalue = [4, 21, 0]'),
#  Text(0.31343283582089554, 0.3181818181818182, 'MaximumTorque <= 230.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2, 0]'),
#  Text(0.31144278606965176, 0.22727272727272727, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.3154228855721393, 0.22727272727272727, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.3174129353233831, 0.3181818181818182, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19, 0]'),
#  Text(0.32935323383084575, 0.4090909090909091, 'FuelTankCapacity <= 81.0\nentropy = 0.427\nsamples = 848\nvalue = [2, 68, 778]'),
#  Text(0.32736318407960197, 0.3181818181818182, 'FuelTankCapacity <= 63.3\nentropy = 0.411\nsamples = 844\nvalue = [2, 64, 778]'),
#  Text(0.3194029850746269, 0.22727272727272727, 'Range <= 835.0\nentropy = 0.5\nsamples = 583\nvalue = [2, 58, 523]'),
#  Text(0.3154228855721393, 0.13636363636363635, 'FuelConsumption <= 10.9\nentropy = 0.337\nsamples = 376\nvalue = [1, 21, 354]'),
#  Text(0.31343283582089554, 0.045454545454545456, 'entropy = 0.296\nsamples = 370\nvalue = [1, 17, 352]'),
#  Text(0.3174129353233831, 0.045454545454545456, 'entropy = 0.918\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.32338308457711445, 0.13636363636363635, 'Range <= 948.5\nentropy = 0.72\nsamples = 207\nvalue = [1, 37, 169]'),
#  Text(0.32139303482587067, 0.045454545454545456, 'entropy = 0.803\nsamples = 143\nvalue = [0, 35, 108]'),
#  Text(0.3253731343283582, 0.045454545454545456, 'entropy = 0.316\nsamples = 64\nvalue = [1, 2, 61]'),
#  Text(0.3353233830845771, 0.22727272727272727, 'FuelTankCapacity <= 73.5\nentropy = 0.158\nsamples = 261\nvalue = [0, 6, 255]'),
#  Text(0.33134328358208953, 0.13636363636363635, 'FuelTankCapacity <= 69.0\nentropy = 0.073\nsamples = 226\nvalue = [0, 2, 224]'),
#  Text(0.32935323383084575, 0.045454545454545456, 'entropy = 0.0\nsamples = 121\nvalue = [0, 0, 121]'),
#  Text(0.3333333333333333, 0.045454545454545456, 'entropy = 0.136\nsamples = 105\nvalue = [0, 2, 103]'),
#  Text(0.33930348258706466, 0.13636363636363635, 'CarName <= 19109.5\nentropy = 0.513\nsamples = 35\nvalue = [0, 4, 31]'),
#  Text(0.3373134328358209, 0.045454545454545456, 'entropy = 0.235\nsamples = 26\nvalue = [0, 1, 25]'),
#  Text(0.34129353233830845, 0.045454545454545456, 'entropy = 0.918\nsamples = 9\nvalue = [0, 3, 6]'),
#  Text(0.33134328358208953, 0.3181818181818182, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.3723880597014925, 0.5, 'MaximumTorque <= 420.5\nentropy = 0.243\nsamples = 1729\nvalue = [12, 48, 1669]'),
#  Text(0.3616915422885572, 0.4090909090909091, 'FuelTankCapacity <= 61.5\nentropy = 0.154\nsamples = 1530\nvalue = [12, 17, 1501]'),
#  Text(0.3522388059701492, 0.3181818181818182, 'MaximumTorque <= 395.0\nentropy = 0.195\nsamples = 635\nvalue = [1, 17, 617]'),
#  Text(0.345273631840796, 0.22727272727272727, 'FuelTankCapacity <= 55.5\nentropy = 0.099\nsamples = 515\nvalue = [1, 5, 509]'),
#  Text(0.34328358208955223, 0.13636363636363635, 'entropy = 0.0\nsamples = 291\nvalue = [0, 0, 291]'),
#  Text(0.3472636815920398, 0.13636363636363635, 'CO2Emissions <= 271.0\nentropy = 0.195\nsamples = 224\nvalue = [1, 5, 218]'),
#  Text(0.345273631840796, 0.045454545454545456, 'entropy = 0.171\nsamples = 223\nvalue = [1, 4, 218]'),
#  Text(0.3492537313432836, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3592039800995025, 0.22727272727272727, 'Drivetrain <= 1.5\nentropy = 0.469\nsamples = 120\nvalue = [0, 12, 108]'),
#  Text(0.35522388059701493, 0.13636363636363635, 'CarName <= 23040.5\nentropy = 0.297\nsamples = 95\nvalue = [0, 5, 90]'),
#  Text(0.35323383084577115, 0.045454545454545456, 'entropy = 0.254\nsamples = 94\nvalue = [0, 4, 90]'),
#  Text(0.3572139303482587, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.36318407960199006, 0.13636363636363635, 'CarName <= 10127.0\nentropy = 0.855\nsamples = 25\nvalue = [0, 7, 18]'),
#  Text(0.3611940298507463, 0.045454545454545456, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 17]'),
#  Text(0.36517412935323385, 0.045454545454545456, 'entropy = 0.544\nsamples = 8\nvalue = [0, 7, 1]'),
#  Text(0.3711442786069652, 0.3181818181818182, 'FuelConsumption <= 6.55\nentropy = 0.096\nsamples = 895\nvalue = [11, 0, 884]'),
#  Text(0.3691542288557214, 0.22727272727272727, 'CO2Emissions <= 142.5\nentropy = 0.186\nsamples = 388\nvalue = [11, 0, 377]'),
#  Text(0.36716417910447763, 0.13636363636363635, 'entropy = 0.0\nsamples = 258\nvalue = [0, 0, 258]'),
#  Text(0.3711442786069652, 0.13636363636363635, 'FuelTankCapacity <= 68.5\nentropy = 0.418\nsamples = 130\nvalue = [11, 0, 119]'),
#  Text(0.3691542288557214, 0.045454545454545456, 'entropy = 0.0\nsamples = 74\nvalue = [0, 0, 74]'),
#  Text(0.373134328358209, 0.045454545454545456, 'entropy = 0.715\nsamples = 56\nvalue = [11, 0, 45]'),
#  Text(0.373134328358209, 0.22727272727272727, 'entropy = 0.0\nsamples = 507\nvalue = [0, 0, 507]'),
#  Text(0.38308457711442784, 0.4090909090909091, 'MaximumTorque <= 460.0\nentropy = 0.624\nsamples = 199\nvalue = [0, 31, 168]'),
#  Text(0.38109452736318405, 0.3181818181818182, 'FuelConsumption <= 5.6\nentropy = 0.936\nsamples = 88\nvalue = [0, 31, 57]'),
#  Text(0.37910447761194027, 0.22727272727272727, 'entropy = 0.0\nsamples = 33\nvalue = [0, 0, 33]'),
#  Text(0.38308457711442784, 0.22727272727272727, 'EngineType <= 4.5\nentropy = 0.988\nsamples = 55\nvalue = [0, 31, 24]'),
#  Text(0.37910447761194027, 0.13636363636363635, 'CO2Emissions <= 150.5\nentropy = 0.391\nsamples = 26\nvalue = [0, 24, 2]'),
#  Text(0.37711442786069654, 0.045454545454545456, 'entropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.38109452736318405, 0.045454545454545456, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23, 0]'),
#  Text(0.3870646766169154, 0.13636363636363635, 'FuelTankCapacity <= 73.0\nentropy = 0.797\nsamples = 29\nvalue = [0, 7, 22]'),
#  Text(0.3850746268656716, 0.045454545454545456, 'entropy = 0.0\nsamples = 18\nvalue = [0, 0, 18]'),
#  Text(0.3890547263681592, 0.045454545454545456, 'entropy = 0.946\nsamples = 11\nvalue = [0, 7, 4]'),
#  Text(0.3850746268656716, 0.3181818181818182, 'entropy = 0.0\nsamples = 111\nvalue = [0, 0, 111]'),
#  Text(0.6759950248756219, 0.8636363636363636, 'Acceleration <= 2.5\nentropy = 1.31\nsamples = 12519\nvalue = [6337, 5207, 975]'),
#  Text(0.5197761194029851, 0.7727272727272727, 'MaximumPower <= 1.5\nentropy = 1.276\nsamples = 6286\nvalue = [1216, 4103, 967]'),
#  Text(0.4332089552238806, 0.6818181818181818, 'MaximumTorque <= 146.5\nentropy = 0.998\nsamples = 1543\nvalue = [640, 900, 3]'),
#  Text(0.4039800995024876, 0.5909090909090909, 'Range <= 894.5\nentropy = 0.795\nsamples = 396\nvalue = [301, 95, 0]'),
#  Text(0.4019900497512438, 0.5, 'MaximumTorque <= 122.5\nentropy = 0.872\nsamples = 325\nvalue = [230, 95, 0]'),
#  Text(0.4, 0.4090909090909091, 'entropy = 0.0\nsamples = 53\nvalue = [53, 0, 0]'),
#  Text(0.4039800995024876, 0.4090909090909091, 'CarName <= 16760.5\nentropy = 0.933\nsamples = 272\nvalue = [177, 95, 0]'),
#  Text(0.3970149253731343, 0.3181818181818182, 'MaximumTorque <= 132.5\nentropy = 0.856\nsamples = 214\nvalue = [154, 60, 0]'),
#  Text(0.39303482587064675, 0.22727272727272727, 'CarName <= 1657.5\nentropy = 0.461\nsamples = 82\nvalue = [74, 8, 0]'),
#  Text(0.39104477611940297, 0.13636363636363635, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.39502487562189054, 0.13636363636363635, 'FuelConsumption <= 5.35\nentropy = 0.292\nsamples = 78\nvalue = [74, 4, 0]'),
#  Text(0.39303482587064675, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.3970149253731343, 0.045454545454545456, 'entropy = 0.176\nsamples = 76\nvalue = [74, 2, 0]'),
#  Text(0.4009950248756219, 0.22727272727272727, 'CO2Emissions <= 98.5\nentropy = 0.967\nsamples = 132\nvalue = [80, 52, 0]'),
#  Text(0.3990049751243781, 0.13636363636363635, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(0.40298507462686567, 0.13636363636363635, 'FuelTankCapacity <= 45.5\nentropy = 0.984\nsamples = 122\nvalue = [70, 52, 0]'),
#  Text(0.4009950248756219, 0.045454545454545456, 'entropy = 0.954\nsamples = 32\nvalue = [12, 20, 0]'),
#  Text(0.40497512437810945, 0.045454545454545456, 'entropy = 0.939\nsamples = 90\nvalue = [58, 32, 0]'),
#  Text(0.4109452736318408, 0.3181818181818182, 'CarName <= 17434.5\nentropy = 0.969\nsamples = 58\nvalue = [23, 35, 0]'),
#  Text(0.408955223880597, 0.22727272727272727, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(0.4129353233830846, 0.22727272727272727, 'FuelConsumption <= 8.15\nentropy = 1.0\nsamples = 45\nvalue = [23, 22, 0]'),
#  Text(0.4109452736318408, 0.13636363636363635, 'CarName <= 20083.5\nentropy = 0.982\nsamples = 38\nvalue = [16, 22, 0]'),
#  Text(0.408955223880597, 0.045454545454545456, 'entropy = 0.811\nsamples = 20\nvalue = [15, 5, 0]'),
#  Text(0.4129353233830846, 0.045454545454545456, 'entropy = 0.31\nsamples = 18\nvalue = [1, 17, 0]'),
#  Text(0.41492537313432837, 0.13636363636363635, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.4059701492537313, 0.5, 'entropy = 0.0\nsamples = 71\nvalue = [71, 0, 0]'),
#  Text(0.46243781094527364, 0.5909090909090909, 'FuelTankCapacity <= 48.5\nentropy = 0.901\nsamples = 1147\nvalue = [339, 805, 3]'),
#  Text(0.4368159203980099, 0.5, 'CarName <= 11348.5\nentropy = 0.994\nsamples = 354\nvalue = [161, 193, 0]'),
#  Text(0.4228855721393035, 0.4090909090909091, 'CarName <= 1177.0\nentropy = 0.876\nsamples = 125\nvalue = [88, 37, 0]'),
#  Text(0.4208955223880597, 0.3181818181818182, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.4248756218905473, 0.3181818181818182, 'CO2Emissions <= 108.5\nentropy = 0.797\nsamples = 116\nvalue = [88, 28, 0]'),
#  Text(0.4208955223880597, 0.22727272727272727, 'Range <= 977.0\nentropy = 0.528\nsamples = 67\nvalue = [59, 8, 0]'),
#  Text(0.41890547263681593, 0.13636363636363635, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(0.4228855721393035, 0.13636363636363635, 'Range <= 1010.5\nentropy = 0.634\nsamples = 50\nvalue = [42, 8, 0]'),
#  Text(0.4208955223880597, 0.045454545454545456, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.4248756218905473, 0.045454545454545456, 'entropy = 0.496\nsamples = 46\nvalue = [41, 5, 0]'),
#  Text(0.42885572139303485, 0.22727272727272727, 'CO2Emissions <= 111.5\nentropy = 0.976\nsamples = 49\nvalue = [29, 20, 0]'),
#  Text(0.42686567164179107, 0.13636363636363635, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.43084577114427863, 0.13636363636363635, 'FuelTankCapacity <= 41.0\nentropy = 0.893\nsamples = 42\nvalue = [29, 13, 0]'),
#  Text(0.42885572139303485, 0.045454545454545456, 'entropy = 0.764\nsamples = 9\nvalue = [2, 7, 0]'),
#  Text(0.43283582089552236, 0.045454545454545456, 'entropy = 0.684\nsamples = 33\nvalue = [27, 6, 0]'),
#  Text(0.4507462686567164, 0.4090909090909091, 'CO2Emissions <= 122.5\nentropy = 0.903\nsamples = 229\nvalue = [73, 156, 0]'),
#  Text(0.4427860696517413, 0.3181818181818182, 'MaximumTorque <= 232.5\nentropy = 0.98\nsamples = 161\nvalue = [67, 94, 0]'),
#  Text(0.4368159203980099, 0.22727272727272727, 'FuelConsumption <= 4.05\nentropy = 0.985\nsamples = 103\nvalue = [59, 44, 0]'),
#  Text(0.43482587064676614, 0.13636363636363635, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0, 0]'),
#  Text(0.4388059701492537, 0.13636363636363635, 'MaximumTorque <= 165.0\nentropy = 1.0\nsamples = 86\nvalue = [42, 44, 0]'),
#  Text(0.4368159203980099, 0.045454545454545456, 'entropy = 0.625\nsamples = 32\nvalue = [27, 5, 0]'),
#  Text(0.4407960199004975, 0.045454545454545456, 'entropy = 0.852\nsamples = 54\nvalue = [15, 39, 0]'),
#  Text(0.4487562189054726, 0.22727272727272727, 'Range <= 1233.0\nentropy = 0.579\nsamples = 58\nvalue = [8, 50, 0]'),
#  Text(0.44676616915422884, 0.13636363636363635, 'FuelConsumption <= 4.1\nentropy = 0.811\nsamples = 32\nvalue = [8, 24, 0]'),
#  Text(0.44477611940298506, 0.045454545454545456, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.4487562189054726, 0.045454545454545456, 'entropy = 0.242\nsamples = 25\nvalue = [1, 24, 0]'),
#  Text(0.4507462686567164, 0.13636363636363635, 'entropy = 0.0\nsamples = 26\nvalue = [0, 26, 0]'),
#  Text(0.45870646766169154, 0.3181818181818182, 'MaximumTorque <= 167.5\nentropy = 0.431\nsamples = 68\nvalue = [6, 62, 0]'),
#  Text(0.45671641791044776, 0.22727272727272727, 'MaximumTorque <= 155.0\nentropy = 0.811\nsamples = 24\nvalue = [6, 18, 0]'),
#  Text(0.454726368159204, 0.13636363636363635, 'FuelConsumption <= 8.1\nentropy = 0.297\nsamples = 19\nvalue = [1, 18, 0]'),
#  Text(0.4527363184079602, 0.045454545454545456, 'entropy = 0.0\nsamples = 18\nvalue = [0, 18, 0]'),
#  Text(0.45671641791044776, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.45870646766169154, 0.13636363636363635, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.4606965174129353, 0.22727272727272727, 'entropy = 0.0\nsamples = 44\nvalue = [0, 44, 0]'),
#  Text(0.4880597014925373, 0.5, 'CarName <= 20402.0\nentropy = 0.803\nsamples = 793\nvalue = [178, 612, 3]'),
#  Text(0.481592039800995, 0.4090909090909091, 'CarName <= 19584.5\nentropy = 0.861\nsamples = 684\nvalue = [176, 505, 3]'),
#  Text(0.4746268656716418, 0.3181818181818182, 'CarName <= 15110.5\nentropy = 0.821\nsamples = 660\nvalue = [153, 504, 3]'),
#  Text(0.4666666666666667, 0.22727272727272727, 'CarName <= 3272.5\nentropy = 0.95\nsamples = 394\nvalue = [121, 270, 3]'),
#  Text(0.4626865671641791, 0.13636363636363635, 'CarName <= 297.0\nentropy = 0.65\nsamples = 95\nvalue = [9, 83, 3]'),
#  Text(0.4606965174129353, 0.045454545454545456, 'entropy = 0.469\nsamples = 10\nvalue = [9, 1, 0]'),
#  Text(0.4646766169154229, 0.045454545454545456, 'entropy = 0.22\nsamples = 85\nvalue = [0, 82, 3]'),
#  Text(0.47064676616915424, 0.13636363636363635, 'MaximumTorque <= 235.0\nentropy = 0.954\nsamples = 299\nvalue = [112, 187, 0]'),
#  Text(0.46865671641791046, 0.045454545454545456, 'entropy = 1.0\nsamples = 177\nvalue = [88, 89, 0]'),
#  Text(0.472636815920398, 0.045454545454545456, 'entropy = 0.715\nsamples = 122\nvalue = [24, 98, 0]'),
#  Text(0.48258706467661694, 0.22727272727272727, 'CO2Emissions <= 167.5\nentropy = 0.53\nsamples = 266\nvalue = [32, 234, 0]'),
#  Text(0.4786069651741294, 0.13636363636363635, 'CarName <= 18339.5\nentropy = 0.426\nsamples = 253\nvalue = [22, 231, 0]'),
#  Text(0.4766169154228856, 0.045454545454545456, 'entropy = 0.297\nsamples = 228\nvalue = [12, 216, 0]'),
#  Text(0.48059701492537316, 0.045454545454545456, 'entropy = 0.971\nsamples = 25\nvalue = [10, 15, 0]'),
#  Text(0.48656716417910445, 0.13636363636363635, 'CarName <= 18772.5\nentropy = 0.779\nsamples = 13\nvalue = [10, 3, 0]'),
#  Text(0.4845771144278607, 0.045454545454545456, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.48855721393034823, 0.045454545454545456, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.48855721393034823, 0.3181818181818182, 'EngineType <= 3.5\nentropy = 0.25\nsamples = 24\nvalue = [23, 1, 0]'),
#  Text(0.48656716417910445, 0.22727272727272727, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.490547263681592, 0.22727272727272727, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0, 0]'),
#  Text(0.4945273631840796, 0.4090909090909091, 'CO2Emissions <= 176.0\nentropy = 0.132\nsamples = 109\nvalue = [2, 107, 0]'),
#  Text(0.4925373134328358, 0.3181818181818182, 'entropy = 0.0\nsamples = 107\nvalue = [0, 107, 0]'),
#  Text(0.49651741293532337, 0.3181818181818182, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6063432835820896, 0.6818181818181818, 'MaximumPower <= 2.5\nentropy = 1.219\nsamples = 4743\nvalue = [576, 3203, 964]'),
#  Text(0.5726368159203981, 0.5909090909090909, 'MaximumTorque <= 381.5\nentropy = 1.081\nsamples = 3647\nvalue = [449, 2707, 491]'),
#  Text(0.5512437810945273, 0.5, 'FuelTankCapacity <= 60.5\nentropy = 1.051\nsamples = 3593\nvalue = [397, 2706, 490]'),
#  Text(0.5223880597014925, 0.4090909090909091, 'CarName <= 11429.5\nentropy = 0.939\nsamples = 2217\nvalue = [288, 1754, 175]'),
#  Text(0.5064676616915423, 0.3181818181818182, 'CarName <= 7321.0\nentropy = 1.049\nsamples = 1065\nvalue = [195, 790, 80]'),
#  Text(0.49850746268656715, 0.22727272727272727, 'MaximumTorque <= 325.0\nentropy = 0.905\nsamples = 709\nvalue = [72, 571, 66]'),
#  Text(0.4945273631840796, 0.13636363636363635, 'CarName <= 3225.5\nentropy = 0.842\nsamples = 612\nvalue = [71, 503, 38]'),
#  Text(0.4925373134328358, 0.045454545454545456, 'entropy = 0.69\nsamples = 139\nvalue = [1, 116, 22]'),
#  Text(0.49651741293532337, 0.045454545454545456, 'entropy = 0.81\nsamples = 473\nvalue = [70, 387, 16]'),
#  Text(0.5024875621890548, 0.13636363636363635, 'Range <= 1294.0\nentropy = 0.945\nsamples = 97\nvalue = [1, 68, 28]'),
#  Text(0.5004975124378109, 0.045454545454545456, 'entropy = 0.643\nsamples = 79\nvalue = [1, 68, 10]'),
#  Text(0.5044776119402985, 0.045454545454545456, 'entropy = 0.0\nsamples = 18\nvalue = [0, 0, 18]'),
#  Text(0.5144278606965174, 0.22727272727272727, 'CarName <= 8693.0\nentropy = 1.145\nsamples = 356\nvalue = [123, 219, 14]'),
#  Text(0.5104477611940299, 0.13636363636363635, 'Range <= 1150.5\nentropy = 1.0\nsamples = 148\nvalue = [74, 74, 0]'),
#  Text(0.5084577114427861, 0.045454545454545456, 'entropy = 0.951\nsamples = 116\nvalue = [73, 43, 0]'),
#  Text(0.5124378109452736, 0.045454545454545456, 'entropy = 0.201\nsamples = 32\nvalue = [1, 31, 0]'),
#  Text(0.5184079601990049, 0.13636363636363635, 'CarName <= 10966.5\nentropy = 1.116\nsamples = 208\nvalue = [49, 145, 14]'),
#  Text(0.5164179104477612, 0.045454545454545456, 'entropy = 0.908\nsamples = 168\nvalue = [19, 135, 14]'),
#  Text(0.5203980099502488, 0.045454545454545456, 'entropy = 0.811\nsamples = 40\nvalue = [30, 10, 0]'),
#  Text(0.5383084577114428, 0.3181818181818182, 'CarName <= 18560.5\nentropy = 0.805\nsamples = 1152\nvalue = [93, 964, 95]'),
#  Text(0.5303482587064676, 0.22727272727272727, 'CarName <= 18489.0\nentropy = 0.646\nsamples = 723\nvalue = [24, 633, 66]'),
#  Text(0.5263681592039801, 0.13636363636363635, 'CO2Emissions <= 164.5\nentropy = 0.616\nsamples = 711\nvalue = [24, 629, 58]'),
#  Text(0.5243781094527363, 0.045454545454545456, 'entropy = 0.554\nsamples = 557\nvalue = [22, 503, 32]'),
#  Text(0.5283582089552239, 0.045454545454545456, 'entropy = 0.752\nsamples = 154\nvalue = [2, 126, 26]'),
#  Text(0.5343283582089552, 0.13636363636363635, 'Range <= 1121.5\nentropy = 0.918\nsamples = 12\nvalue = [0, 4, 8]'),
#  Text(0.5323383084577115, 0.045454545454545456, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.536318407960199, 0.045454545454545456, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8]'),
#  Text(0.5462686567164179, 0.22727272727272727, 'CarName <= 19738.0\nentropy = 0.975\nsamples = 429\nvalue = [69, 331, 29]'),
#  Text(0.5422885572139303, 0.13636363636363635, 'CarName <= 19491.5\nentropy = 0.975\nsamples = 189\nvalue = [59, 128, 2]'),
#  Text(0.5402985074626866, 0.045454545454545456, 'entropy = 0.855\nsamples = 147\nvalue = [32, 113, 2]'),
#  Text(0.5442786069651742, 0.045454545454545456, 'entropy = 0.94\nsamples = 42\nvalue = [27, 15, 0]'),
#  Text(0.5502487562189055, 0.13636363636363635, 'CO2Emissions <= 205.5\nentropy = 0.75\nsamples = 240\nvalue = [10, 203, 27]'),
#  Text(0.5482587064676617, 0.045454545454545456, 'entropy = 0.651\nsamples = 233\nvalue = [5, 202, 26]'),
#  Text(0.5522388059701493, 0.045454545454545456, 'entropy = 1.149\nsamples = 7\nvalue = [5, 1, 1]'),
#  Text(0.5800995024875621, 0.4090909090909091, 'CarName <= 21626.0\nentropy = 1.144\nsamples = 1376\nvalue = [109, 952, 315]'),
#  Text(0.5701492537313433, 0.3181818181818182, 'CarName <= 16386.5\nentropy = 1.163\nsamples = 1233\nvalue = [90, 829, 314]'),
# ...
#  Text(0.7810945273631841, 0.045454545454545456, 'entropy = 0.0\nsamples = 25\nvalue = [25, 0, 0]'),
#  Text(0.7850746268656716, 0.045454545454545456, 'entropy = 0.715\nsamples = 117\nvalue = [94, 23, 0]'),
#  Text(0.7890547263681592, 0.22727272727272727, 'CarName <= 7235.0\nentropy = 0.431\nsamples = 385\nvalue = [351, 34, 0]'),
#  Text(0.7870646766169154, 0.13636363636363635, 'entropy = 0.0\nsamples = 129\nvalue = [129, 0, 0]'),
#  Text(0.7910447761194029, 0.13636363636363635, 'FuelConsumption <= 5.15\nentropy = 0.565\nsamples = 256\nvalue = [222, 34, 0]'),
#  Text(0.7890547263681592, 0.045454545454545456, 'entropy = 0.685\nsamples = 181\nvalue = [148, 33, 0]'),
#  Text(0.7930348258706468, 0.045454545454545456, 'entropy = 0.102\nsamples = 75\nvalue = [74, 1, 0]'),
#  Text(0.8049751243781095, 0.3181818181818182, 'MaximumTorque <= 237.5\nentropy = 0.852\nsamples = 252\nvalue = [182, 70, 0]'),
#  Text(0.8009950248756219, 0.22727272727272727, 'CarName <= 1503.0\nentropy = 0.102\nsamples = 75\nvalue = [74, 1, 0]'),
#  Text(0.7990049751243781, 0.13636363636363635, 'EngineType <= 3.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.7970149253731343, 0.045454545454545456, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.8009950248756219, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8029850746268656, 0.13636363636363635, 'entropy = 0.0\nsamples = 70\nvalue = [70, 0, 0]'),
#  Text(0.808955223880597, 0.22727272727272727, 'CarName <= 2105.5\nentropy = 0.965\nsamples = 177\nvalue = [108, 69, 0]'),
#  Text(0.8069651741293532, 0.13636363636363635, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14, 0]'),
#  Text(0.8109452736318408, 0.13636363636363635, 'CarName <= 15624.0\nentropy = 0.922\nsamples = 163\nvalue = [108, 55, 0]'),
#  Text(0.808955223880597, 0.045454545454545456, 'entropy = 0.797\nsamples = 116\nvalue = [88, 28, 0]'),
#  Text(0.8129353233830846, 0.045454545454545456, 'entropy = 0.984\nsamples = 47\nvalue = [20, 27, 0]'),
#  Text(0.8208955223880597, 0.4090909090909091, 'Range <= 1199.0\nentropy = 0.984\nsamples = 47\nvalue = [20, 27, 0]'),
#  Text(0.8189054726368159, 0.3181818181818182, 'CarName <= 21035.5\nentropy = 0.977\nsamples = 34\nvalue = [20, 14, 0]'),
#  Text(0.8169154228855722, 0.22727272727272727, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.8208955223880597, 0.22727272727272727, 'CarName <= 22160.5\nentropy = 0.863\nsamples = 28\nvalue = [20, 8, 0]'),
#  Text(0.8189054726368159, 0.13636363636363635, 'CarName <= 21131.5\nentropy = 0.65\nsamples = 24\nvalue = [20, 4, 0]'),
#  Text(0.8169154228855722, 0.045454545454545456, 'entropy = 0.971\nsamples = 10\nvalue = [6, 4, 0]'),
#  Text(0.8208955223880597, 0.045454545454545456, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0, 0]'),
#  Text(0.8228855721393035, 0.13636363636363635, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.8228855721393035, 0.3181818181818182, 'entropy = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(0.8348258706467662, 0.5, 'Range <= 1336.0\nentropy = 1.0\nsamples = 173\nvalue = [87, 86, 0]'),
#  Text(0.8328358208955224, 0.4090909090909091, 'CO2Emissions <= 168.0\nentropy = 0.943\nsamples = 136\nvalue = [87, 49, 0]'),
#  Text(0.8308457711442786, 0.3181818181818182, 'MaximumTorque <= 265.0\nentropy = 0.997\nsamples = 105\nvalue = [56, 49, 0]'),
#  Text(0.8288557213930349, 0.22727272727272727, 'FuelTankCapacity <= 61.5\nentropy = 0.988\nsamples = 87\nvalue = [38, 49, 0]'),
#  Text(0.826865671641791, 0.13636363636363635, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.8308457711442786, 0.13636363636363635, 'Range <= 992.5\nentropy = 1.0\nsamples = 75\nvalue = [38, 37, 0]'),
#  Text(0.8288557213930349, 0.045454545454545456, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.8328358208955224, 0.045454545454545456, 'entropy = 0.995\nsamples = 70\nvalue = [38, 32, 0]'),
#  Text(0.8328358208955224, 0.22727272727272727, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0]'),
#  Text(0.8348258706467662, 0.3181818181818182, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0, 0]'),
#  Text(0.83681592039801, 0.4090909090909091, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.8960199004975125, 0.6818181818181818, 'Drivetrain <= 0.5\nentropy = 1.04\nsamples = 1471\nvalue = [779, 684, 8]'),
#  Text(0.8656716417910447, 0.5909090909090909, 'CarName <= 21163.0\nentropy = 0.607\nsamples = 336\nvalue = [286, 50, 0]'),
#  Text(0.8567164179104477, 0.5, 'CarName <= 2891.0\nentropy = 0.514\nsamples = 314\nvalue = [278, 36, 0]'),
#  Text(0.854726368159204, 0.4090909090909091, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.8587064676616916, 0.4090909090909091, 'FuelTankCapacity <= 72.5\nentropy = 0.47\nsamples = 309\nvalue = [278, 31, 0]'),
#  Text(0.8507462686567164, 0.3181818181818182, 'CO2Emissions <= 216.5\nentropy = 0.644\nsamples = 183\nvalue = [153, 30, 0]'),
#  Text(0.8427860696517413, 0.22727272727272727, 'FuelTankCapacity <= 59.0\nentropy = 0.784\nsamples = 120\nvalue = [92, 28, 0]'),
#  Text(0.8388059701492537, 0.13636363636363635, 'Range <= 707.5\nentropy = 0.151\nsamples = 46\nvalue = [45, 1, 0]'),
#  Text(0.83681592039801, 0.045454545454545456, 'entropy = 0.592\nsamples = 7\nvalue = [6, 1, 0]'),
#  Text(0.8407960199004975, 0.045454545454545456, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.8467661691542289, 0.13636363636363635, 'MaximumTorque <= 382.5\nentropy = 0.947\nsamples = 74\nvalue = [47, 27, 0]'),
#  Text(0.844776119402985, 0.045454545454545456, 'entropy = 0.99\nsamples = 61\nvalue = [34, 27, 0]'),
#  Text(0.8487562189054726, 0.045454545454545456, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0, 0]'),
#  Text(0.8587064676616916, 0.22727272727272727, 'FuelTankCapacity <= 59.5\nentropy = 0.203\nsamples = 63\nvalue = [61, 2, 0]'),
#  Text(0.854726368159204, 0.13636363636363635, 'FuelConsumption <= 9.55\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.8527363184079602, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8567164179104477, 0.045454545454545456, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.8626865671641791, 0.13636363636363635, 'EngineType <= 4.5\nentropy = 0.124\nsamples = 59\nvalue = [58, 1, 0]'),
#  Text(0.8606965174129353, 0.045454545454545456, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.8646766169154229, 0.045454545454545456, 'entropy = 0.503\nsamples = 9\nvalue = [8, 1, 0]'),
#  Text(0.8666666666666667, 0.3181818181818182, 'CO2Emissions <= 249.5\nentropy = 0.067\nsamples = 126\nvalue = [125, 1, 0]'),
#  Text(0.8646766169154229, 0.22727272727272727, 'entropy = 0.0\nsamples = 104\nvalue = [104, 0, 0]'),
#  Text(0.8686567164179104, 0.22727272727272727, 'FuelConsumption <= 9.45\nentropy = 0.267\nsamples = 22\nvalue = [21, 1, 0]'),
#  Text(0.8666666666666667, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8706467661691543, 0.13636363636363635, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0, 0]'),
#  Text(0.8746268656716418, 0.5, 'MaximumTorque <= 370.0\nentropy = 0.946\nsamples = 22\nvalue = [8, 14, 0]'),
#  Text(0.872636815920398, 0.4090909090909091, 'CarName <= 21864.5\nentropy = 0.997\nsamples = 15\nvalue = [8, 7, 0]'),
#  Text(0.8706467661691543, 0.3181818181818182, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.8746268656716418, 0.3181818181818182, 'CarName <= 23255.0\nentropy = 0.503\nsamples = 9\nvalue = [8, 1, 0]'),
#  Text(0.872636815920398, 0.22727272727272727, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.8766169154228856, 0.22727272727272727, 'FuelConsumption <= 8.7\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8746268656716418, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8786069651741294, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8766169154228856, 0.4090909090909091, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.9263681592039801, 0.5909090909090909, 'CarName <= 4229.5\nentropy = 1.042\nsamples = 1135\nvalue = [493, 634, 8]'),
#  Text(0.8990049751243782, 0.5, 'CO2Emissions <= 242.0\nentropy = 0.726\nsamples = 133\nvalue = [23, 109, 1]'),
#  Text(0.891542288557214, 0.4090909090909091, 'CarName <= 3704.5\nentropy = 0.606\nsamples = 128\nvalue = [19, 109, 0]'),
#  Text(0.882587064676617, 0.3181818181818182, 'CarName <= 3158.0\nentropy = 0.903\nsamples = 47\nvalue = [15, 32, 0]'),
#  Text(0.8805970149253731, 0.22727272727272727, 'entropy = 0.0\nsamples = 28\nvalue = [0, 28, 0]'),
#  Text(0.8845771144278607, 0.22727272727272727, 'EngineType <= 3.5\nentropy = 0.742\nsamples = 19\nvalue = [15, 4, 0]'),
#  Text(0.882587064676617, 0.13636363636363635, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8865671641791045, 0.13636363636363635, 'FuelTankCapacity <= 53.0\nentropy = 0.523\nsamples = 17\nvalue = [15, 2, 0]'),
#  Text(0.8845771144278607, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8885572139303483, 0.045454545454545456, 'entropy = 0.337\nsamples = 16\nvalue = [15, 1, 0]'),
#  Text(0.900497512437811, 0.3181818181818182, 'FuelTankCapacity <= 75.5\nentropy = 0.284\nsamples = 81\nvalue = [4, 77, 0]'),
#  Text(0.8965174129353234, 0.22727272727272727, 'CO2Emissions <= 103.5\nentropy = 0.101\nsamples = 76\nvalue = [1, 75, 0]'),
#  Text(0.8945273631840795, 0.13636363636363635, 'CarName <= 4119.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.8925373134328358, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8965174129353234, 0.045454545454545456, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8985074626865671, 0.13636363636363635, 'entropy = 0.0\nsamples = 72\nvalue = [0, 72, 0]'),
#  Text(0.9044776119402985, 0.22727272727272727, 'CarName <= 3911.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.9024875621890547, 0.13636363636363635, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.9064676616915422, 0.13636363636363635, 'FuelConsumption <= 7.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.9044776119402985, 0.045454545454545456, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9084577114427861, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.9064676616915422, 0.4090909090909091, 'CO2Emissions <= 245.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 0, 1]'),
#  Text(0.9044776119402985, 0.3181818181818182, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9084577114427861, 0.3181818181818182, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.9537313432835821, 0.5, 'CarName <= 11599.5\nentropy = 1.051\nsamples = 1002\nvalue = [470, 525, 7]'),
#  Text(0.9338308457711443, 0.4090909090909091, 'MaximumPower <= 2.5\nentropy = 1.022\nsamples = 401\nvalue = [242, 156, 3]'),
#  Text(0.9253731343283582, 0.3181818181818182, 'CarName <= 10193.5\nentropy = 0.991\nsamples = 367\nvalue = [238, 126, 3]'),
#  Text(0.918407960199005, 0.22727272727272727, 'Drivetrain <= 1.5\nentropy = 1.067\nsamples = 270\nvalue = [149, 118, 3]'),
#  Text(0.9144278606965174, 0.13636363636363635, 'Range <= 1494.5\nentropy = 0.993\nsamples = 236\nvalue = [146, 89, 1]'),
#  Text(0.9124378109452737, 0.045454545454545456, 'entropy = 0.961\nsamples = 220\nvalue = [145, 74, 1]'),
#  Text(0.9164179104477612, 0.045454545454545456, 'entropy = 0.337\nsamples = 16\nvalue = [1, 15, 0]'),
#  Text(0.9223880597014925, 0.13636363636363635, 'FuelConsumption <= 9.6\nentropy = 0.745\nsamples = 34\nvalue = [3, 29, 2]'),
#  Text(0.9203980099502488, 0.045454545454545456, 'entropy = 0.362\nsamples = 29\nvalue = [0, 27, 2]'),
#  Text(0.9243781094527364, 0.045454545454545456, 'entropy = 0.971\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.9323383084577115, 0.22727272727272727, 'FuelTankCapacity <= 64.0\nentropy = 0.411\nsamples = 97\nvalue = [89, 8, 0]'),
#  Text(0.9303482587064676, 0.13636363636363635, 'FuelTankCapacity <= 61.0\nentropy = 0.722\nsamples = 40\nvalue = [32, 8, 0]'),
#  Text(0.9283582089552239, 0.045454545454545456, 'entropy = 0.431\nsamples = 34\nvalue = [31, 3, 0]'),
#  Text(0.9323383084577115, 0.045454545454545456, 'entropy = 0.65\nsamples = 6\nvalue = [1, 5, 0]'),
#  Text(0.9343283582089552, 0.13636363636363635, 'entropy = 0.0\nsamples = 57\nvalue = [57, 0, 0]'),
#  Text(0.9422885572139303, 0.3181818181818182, 'MaximumTorque <= 395.0\nentropy = 0.523\nsamples = 34\nvalue = [4, 30, 0]'),
#  Text(0.9402985074626866, 0.22727272727272727, 'MaximumTorque <= 226.0\nentropy = 0.206\nsamples = 31\nvalue = [1, 30, 0]'),
#  Text(0.9383084577114428, 0.13636363636363635, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9422885572139303, 0.13636363636363635, 'entropy = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.9442786069651742, 0.22727272727272727, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.9736318407960199, 0.4090909090909091, 'CarName <= 13350.5\nentropy = 1.011\nsamples = 601\nvalue = [228, 369, 4]'),
#  Text(0.9582089552238806, 0.3181818181818182, 'Range <= 887.0\nentropy = 0.658\nsamples = 166\nvalue = [20, 143, 3]'),
#  Text(0.9502487562189055, 0.22727272727272727, 'FuelTankCapacity <= 52.5\nentropy = 0.999\nsamples = 72\nvalue = [16, 53, 3]'),
#  Text(0.9462686567164179, 0.13636363636363635, 'CO2Emissions <= 172.5\nentropy = 0.61\nsamples = 20\nvalue = [0, 17, 3]'),
#  Text(0.9442786069651742, 0.045454545454545456, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14, 0]'),
#  Text(0.9482587064676616, 0.045454545454545456, 'entropy = 1.0\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.954228855721393, 0.13636363636363635, 'MaximumTorque <= 160.0\nentropy = 0.89\nsamples = 52\nvalue = [16, 36, 0]'),
#  Text(0.9522388059701492, 0.045454545454545456, 'entropy = 0.764\nsamples = 9\nvalue = [7, 2, 0]'),
#  Text(0.9562189054726368, 0.045454545454545456, 'entropy = 0.74\nsamples = 43\nvalue = [9, 34, 0]'),
#  Text(0.9661691542288557, 0.22727272727272727, 'FuelTankCapacity <= 53.5\nentropy = 0.254\nsamples = 94\nvalue = [4, 90, 0]'),
#  Text(0.9621890547263682, 0.13636363636363635, 'CarName <= 12224.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3, 0]'),
#  Text(0.9601990049751243, 0.045454545454545456, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.9641791044776119, 0.045454545454545456, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.9701492537313433, 0.13636363636363635, 'CarName <= 12980.5\nentropy = 0.155\nsamples = 89\nvalue = [2, 87, 0]'),
#  Text(0.9681592039800995, 0.045454545454545456, 'entropy = 0.0\nsamples = 62\nvalue = [0, 62, 0]'),
#  Text(0.972139303482587, 0.045454545454545456, 'entropy = 0.381\nsamples = 27\nvalue = [2, 25, 0]'),
#  Text(0.9890547263681592, 0.3181818181818182, 'Range <= 1092.5\nentropy = 1.02\nsamples = 435\nvalue = [208, 226, 1]'),
#  Text(0.982089552238806, 0.22727272727272727, 'Drivetrain <= 1.5\nentropy = 0.982\nsamples = 274\nvalue = [101, 172, 1]'),
#  Text(0.9781094527363184, 0.13636363636363635, 'CO2Emissions <= 129.0\nentropy = 0.935\nsamples = 250\nvalue = [79, 170, 1]'),
#  Text(0.9761194029850746, 0.045454545454545456, 'entropy = 0.391\nsamples = 13\nvalue = [12, 1, 0]'),
#  Text(0.9800995024875622, 0.045454545454545456, 'entropy = 0.896\nsamples = 237\nvalue = [67, 169, 1]'),
#  Text(0.9860696517412936, 0.13636363636363635, 'CO2Emissions <= 242.0\nentropy = 0.414\nsamples = 24\nvalue = [22, 2, 0]'),
#  Text(0.9840796019900497, 0.045454545454545456, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0, 0]'),
#  Text(0.9880597014925373, 0.045454545454545456, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.9960199004975124, 0.22727272727272727, 'Range <= 1484.0\nentropy = 0.92\nsamples = 161\nvalue = [107, 54, 0]'),
#  Text(0.9940298507462687, 0.13636363636363635, 'Range <= 1350.0\nentropy = 0.822\nsamples = 144\nvalue = [107, 37, 0]'),
#  Text(0.9920398009950249, 0.045454545454545456, 'entropy = 0.957\nsamples = 95\nvalue = [59, 36, 0]'),
#  Text(0.9960199004975124, 0.045454545454545456, 'entropy = 0.144\nsamples = 49\nvalue = [48, 1, 0]'),
#  Text(0.9980099502487563, 0.13636363636363635, 'entropy = 0.0\nsamples = 17\nvalue = [0, 17, 0]')]

# %%
dump(model, "tree_model.joblib")
# Out:
# ['tree_model.joblib']

# %%
print(model.score(x_test, y_test))
model.best_params_
# Out:
# 0.8707482993197279
# {'criterion': 'entropy', 'max_depth': 10}

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(x_test)

roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')

print("Classification Report:")
print(classification_report(y_test, y_pred))

print("ROC/AUC:", roc_auc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.90      0.90      0.90      2126
#            2       0.80      0.83      0.81      2113
#            3       0.92      0.89      0.90      2082
#
#     accuracy                           0.87      6321
#    macro avg       0.87      0.87      0.87      6321
# weighted avg       0.87      0.87      0.87      6321
#
# ROC/AUC: 0.9620920697980381
